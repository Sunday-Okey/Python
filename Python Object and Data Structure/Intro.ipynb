# %%
1 + 1
# Out:
# 2

# %%
print("Hello World")
# Out:
# Hello World

# %%
print('New')
# Out:
# New

# %% [markdown]
# Here you can write notes

# %%
2 + 1
# Out:
# 3

# %%
2 - 1
# Out:
# 1

# %%
2 * 2
# Out:
# 4

# %%
3 / 2
# Out:
# 1.5

# %% [markdown]
# ## Modulo or "Mod" Operator

# %%
7 / 4
# Out:
# 1.75

# %%
7 % 4
# Out:
# 3

# %%
8 % 3
# Out:
# 2

# %%
50 % 5
# Out:
# 0

# %%
23 % 2
# Out:
# 1

# %%
20 % 2
# Out:
# 0

# %%
2 ** 3
# Out:
# 8

# %%
2 + 10 * 10 + 3
# Out:
# 105

# %%
(2 + 10) * (10 + 3)
# Out:
# 156

# %% [markdown]
# ## Variables

# %%
a = 5

# %%
a
# Out:
# 5

# %%
a = 10

# %%
a
# Out:
# 10

# %%
a + a
# Out:
# 20

# %%
a = a + a

# %%
a
# Out:
# 320

# %%
type(a)
# Out:
# int

# %%
a = 30.1

# %%
type(a)
# Out:
# float

# %%
my_income = 100

tax_rate = 0.1

my_taxes = my_income * tax_rate

# %%
my_taxes
# Out:
# 10.0

# %% [markdown]
# ## Strings

# %%
mystr = 'Hello'

# %%
mystr[-1]
# Out:
# 'o'

# %%
mystr[-2]
# Out:
# 'l'

# %%
mystr[-3]
# Out:
# 'l'

# %%
mystr[-4]
# Out:
# 'e'

# %%
'hello'
# Out:
# 'hello'

# %%
"World"
# Out:
# 'World'

# %%
'This is also a string'
# Out:
# 'This is also a string'

# %%
"I'm going on a run"
# Out:
# "I'm going on a run"

# %%
print('hello')
# Out:
# hello

# %%
print('hello world one')
print('hello world two')
# Out:
# hello world one
# hello world two

# %%
print('hello \tworld')
# Out:
# hello 	world

# %%
len('hello')
# Out:
# 5

# %%
len('I am hungry')
# Out:
# 11

# %%
mystr = "Hello World"

# %%
mystr
# Out:
# 'Hello World'

# %%
mystr[0]
# Out:
# 'H'

# %%
mystr[8]
# Out:
# 'r'

# %%
mystr[9]
# Out:
# 'l'

# %%
mystr[0]
# Out:
# 'H'

# %%
mystr[-2]
# Out:
# 'l'

# %%
mystr[-3]
# Out:
# 'r'

# %%
mystr[-1]
# Out:
# 'd'

# %%
mystr = 'abcdefghijk'

# %%
mystr[2:]
# Out:
# 'cdefghijk'

# %%
mystr[:3]
# Out:
# 'abc'

# %%
mystr[3:6]
# Out:
# 'def'

# %%
mystr[1:3]
# Out:
# 'bc'

# %%
mystr[:]
# Out:
# 'abcdefghijk'

# %%
mystr[::]
# Out:
# 'abcdefghijk'

# %%
mystr[::3]
# Out:
# 'adgj'

# %%
mystr[2:7:2]
# Out:
# 'ceg'

# %%
mystr[::-1]
# Out:
# 'kjihgfedcba'

# %% [markdown]
# ## String Properties and Methods

# %% [markdown]
# ### Immutability

# %%
name = 'Sam'

# %%
# name[0] = 'P' strings don't support item assignment

# %%
last_letters = name[1:]

# %%
last_letters
# Out:
# 'am'

# %%
'P' + last_letters
# Out:
# 'Pam'

# %%
x = 'Hello World'

# %%
 x = x + ' It is beautiful outside!'

# %%
x
# Out:
# 'Hello World It is beautiful outside! It is beautiful outside! It is beautiful outside! It is beautiful outside! It is beautiful outside! It is beautiful outside!'

# %%
letter = 'z'

# %%
letter * 10
# Out:
# 'zzzzzzzzzz'

# %%
2 + 3
# Out:
# 5

# %%
'2' + '3'
# Out:
# '23'

# %% [markdown]
# ## Methods

# %%
x = 'Hello World'

# %%
x.capitalize()
# Out:
# 'Hello world'

# %%
x.title()
# Out:
# 'Hello World'

# %%
x.upper()
# Out:
# 'HELLO WORLD'

# %%
x.lower()
# Out:
# 'hello world'

# %%
x.casefold()
# Out:
# 'hello world'

# %%
x.find('z')
# Out:
# -1

# %%
x.index('e')
# Out:
# 1

# %%
x.split()
# Out:
# ['Hello', 'World']

# %%
x.splitlines()
# Out:
# ['Hello World']

# %%
x = 'Hi this is a string'

# %%
x.split()
# Out:
# ['Hi', 'this', 'is', 'a', 'string']

# %%
x.split('i')
# Out:
# ['H', ' th', 's ', 's a str', 'ng']

# %%
print('')
