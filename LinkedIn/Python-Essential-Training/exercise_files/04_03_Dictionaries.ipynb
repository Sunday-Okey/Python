# %%
from collections import defaultdict

# %% [markdown]
# ## Dictionaries

# %%
animals = {
    'a': 'aardvark',
    'b': 'bear',
    'c': 'cat',
}
animals
# Out:
# {'a': 'aardvark', 'b': 'bear', 'c': 'cat'}

# %%
animals['a']
# Out:
# 'aardvark'

# %%
animals['d'] = 'dog'

# %%
animals
# Out:
# {'a': 'aardvark', 'b': 'bear', 'c': 'cat', 'd': 'dog'}

# %%
animals['a'] = 'antelope'
animals
# Out:
# {'a': 'antelope', 'b': 'bear', 'c': 'cat', 'd': 'dog'}

# %%
animals.keys()
# Out:
# dict_keys(['a', 'b', 'c', 'd'])

# %%
animals.values()
# Out:
# dict_values(['antelope', 'bear', 'cat', 'dog'])

# %%
list(animals.keys())
# Out:
# ['a', 'b', 'c', 'd']

# %%
animals['e']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [11], in <module>
# ----> 1 animals['e']
#
# KeyError: 'e'

# %%
animals.get('a')
# Out:
# 'antelope'

# %%
len(animals)
# Out:
# 4

# %%
animals = {
    'a': ['aardvark', 'antelope'],
    'b': ['bear'],
}

# %%
animals['b'].append('bison')

# %%
animals['c'] = ['cat']

# %%
if 'c' not in animals:
    animals['c'] = []
    
animals['c'].append('cat')

# %% [markdown]
# ### The Default Dict

# %%
animals = defaultdict(list)

# %%
animals
# Out:
# defaultdict(list, {})

# %%
animals['e'].append('elephant')
animals
# Out:
# defaultdict(list, {'e': ['elephant']})

# %%
animals['e'].append('emu')
animals
# Out:
# defaultdict(list, {'e': ['elephant', 'emu']})

# %%
animals['f']
# Out:
# []

# %%
mydict = {'a': 2, 'b':5}

# %%
animals = {
    'a': ['aardvark', 'antelope'],
    'b': ['bear'],
}

# %%
animals['b'].append('bisom')

# %%
animals
# Out:
# {'a': ['aardvark', 'antelope'], 'b': ['bear', 'bisom']}

# %%
animals['c'] = ['cat']

# %%
animals
# Out:
# {'a': ['aardvark', 'antelope'], 'b': ['bear', 'bisom'], 'c': ['cat']}

# %%
animals = defaultdict(list)

# %%
animals
# Out:
# defaultdict(list, {})

# %%
animals['e'].append('elephant')

# %%
animals
# Out:
# defaultdict(list, {'e': ['elephant']})
